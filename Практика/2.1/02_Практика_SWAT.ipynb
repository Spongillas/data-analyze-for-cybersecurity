# %% [markdown]
# <h1> Материалы курса "Анализ данных в инфромационной безопасности" </h1>
#
# <h2> Дополнительные материалы к лекции "Анализ данных" </h2>
# Анализ данных работы промышленной установки Сингапурского университета (SUTD)
#
# https://itrust.sutd.edu.sg/itrust-labs-home/itrust-labs_swat/
#
# <p>Андрей Скороходов, UDV Group</p>
# <p>mail: andrei.skorokhodov@udv.group, telegram: @Spongillas</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.__version__
# Out:
# '2.0.2'

# %% [markdown]
# # 1. Чтение, первичное преобразование и сохранение данных

# %%
filename = 'SWaT_Dataset_Normal_v1.xlsx'

pd.read_excel(filename, nrows=10)
# Out:
#                Unnamed: 0      P1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               Timestamp  FIT101     LIT101      MV101       P101       P102
# 1   22/12/2015 4:30:00 PM       0   124.3135          1          1          1
# 2   22/12/2015 4:30:01 PM       0    124.392          1          1          1
# 3   22/12/2015 4:30:02 PM       0   124.4705          1          1          1
# 4   22/12/2015 4:30:03 PM       0   124.6668          1          1          1
# 5   22/12/2015 4:30:04 PM       0   124.5098          1          1          1
# 6   22/12/2015 4:30:05 PM       0    123.921          1          1          1
# 7   22/12/2015 4:30:06 PM       0   123.5284          1          1          1
# 8   22/12/2015 4:30:07 PM       0   123.4107          1          1          1
# 9   22/12/2015 4:30:08 PM       0   123.2144          1          1          1
#
#          P2 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 43 Unnamed: 44  \
# 0    AIT201     AIT202     AIT203     FIT201  ...        P501        P502
# 1  251.9226   8.313446   312.7916          0  ...           1           1
# 2  251.9226   8.313446   312.7916          0  ...           1           1
# 3  251.9226   8.313446   312.7916          0  ...           1           1
# 4  251.9226   8.313446   312.7916          0  ...           1           1
# 5  251.9226   8.313446   312.7916          0  ...           1           1
# 6  251.9226   8.313446   312.7916          0  ...           1           1
# 7  251.9226   8.313446   312.7916          0  ...           1           1
# 8  251.9226   8.313446   312.7916          0  ...           1           1
# 9  251.9226   8.312805   312.7916          0  ...           1           1
#
#   Unnamed: 45 Unnamed: 46 Unnamed: 47        P6 Unnamed: 49 Unnamed: 50  \
# 0      PIT501      PIT502      PIT503    FIT601        P601        P602
# 1    9.100231           0      3.3485  0.000256           1           1
# 2    9.100231           0      3.3485  0.000256           1           1
# 3    9.100231           0      3.3485  0.000256           1           1
# 4    9.100231           0      3.3485  0.000256           1           1
# 5    9.100231           0      3.3485  0.000256           1           1
# 6    9.100231           0      3.3485  0.000256           1           1
# 7    9.100231           0      3.3485  0.000256           1           1
# 8    9.100231           0      3.3485  0.000256           1           1
# 9    9.100231           0      3.3485  0.000256           1           1
#
#   Unnamed: 51    Unnamed: 52
# 0        P603  Normal/Attack
# 1           1         Normal
# 2           1         Normal
# 3           1         Normal
# 4           1         Normal
# 5           1         Normal
# 6           1         Normal
# 7           1         Normal
# 8           1         Normal
# 9           1         Normal
#
# [10 rows x 53 columns]

# %%
# %%time


df = pd.read_excel(
    filename, #nrows=10,
    header=1,
    #index_col=0
)
df
# Out:
# C:\Users\askorohodov\anaconda3\envs\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# CPU times: total: 4min 27s
# Wall time: 4min 29s
#                      Timestamp    FIT101    LIT101  MV101  P101  P102  \
# 0        22/12/2015 4:30:00 PM  0.000000  124.3135      1     1     1
# 1        22/12/2015 4:30:01 PM  0.000000  124.3920      1     1     1
# 2        22/12/2015 4:30:02 PM  0.000000  124.4705      1     1     1
# 3        22/12/2015 4:30:03 PM  0.000000  124.6668      1     1     1
# 4        22/12/2015 4:30:04 PM  0.000000  124.5098      1     1     1
# ...                        ...       ...       ...    ...   ...   ...
# 494995   28/12/2015 9:59:55 AM  2.460366  523.0430      2     2     1
# 494996   28/12/2015 9:59:56 AM  2.448836  522.9645      2     2     1
# 494997   28/12/2015 9:59:57 AM  2.434744  522.8860      2     2     1
# 494998   28/12/2015 9:59:58 AM  2.428338  522.9252      2     2     1
# 494999   28/12/2015 9:59:59 AM  2.427057  522.8467      2     2     1
#
#           AIT201    AIT202    AIT203    FIT201  ...  P501  P502      PIT501  \
# 0       251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 1       251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 2       251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 3       251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# 4       251.9226  8.313446  312.7916  0.000000  ...     1     1    9.100231
# ...          ...       ...       ...       ...  ...   ...   ...         ...
# 494995  262.0161  8.396437  328.5055  2.442316  ...     2     1  250.817100
# 494996  262.0161  8.396437  328.5055  2.442316  ...     2     1  250.817100
# 494997  262.0161  8.396437  328.6337  2.444879  ...     2     1  250.817100
# 494998  262.0161  8.396437  328.6337  2.445391  ...     2     1  250.817100
# 494999  262.0161  8.396437  328.6337  2.445391  ...     2     1  250.865200
#
#           PIT502    PIT503    FIT601  P601  P602  P603  Normal/Attack
# 0       0.000000    3.3485  0.000256     1     1     1         Normal
# 1       0.000000    3.3485  0.000256     1     1     1         Normal
# 2       0.000000    3.3485  0.000256     1     1     1         Normal
# 3       0.000000    3.3485  0.000256     1     1     1         Normal
# 4       0.000000    3.3485  0.000256     1     1     1         Normal
# ...          ...       ...       ...   ...   ...   ...            ...
# 494995  1.778105  189.8552  0.000128     1     1     1         Normal
# 494996  1.778105  189.5027  0.000128     1     1     1         Normal
# 494997  1.778105  189.5027  0.000128     1     1     1         Normal
# 494998  1.649953  189.5027  0.000128     1     1     1         Normal
# 494999  1.649953  189.5988  0.000128     1     1     1         Normal
#
# [495000 rows x 53 columns]

# %%
df.shape
# Out:
# (495000, 53)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495000 entries, 0 to 494999
# Data columns (total 53 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0    Timestamp     495000 non-null  object
#  1   FIT101         495000 non-null  float64
#  2   LIT101         495000 non-null  float64
#  3   MV101          495000 non-null  int64
#  4   P101           495000 non-null  int64
#  5   P102           495000 non-null  int64
#  6   AIT201         495000 non-null  float64
#  7   AIT202         495000 non-null  float64
#  8   AIT203         495000 non-null  float64
#  9   FIT201         495000 non-null  float64
#  10  MV201          495000 non-null  int64
#  11  P201           495000 non-null  int64
#  12  P202           495000 non-null  int64
#  13  P203           495000 non-null  int64
#  14  P204           495000 non-null  int64
#  15  P205           495000 non-null  int64
#  16  P206           495000 non-null  int64
#  17  DPIT301        495000 non-null  float64
#  18  FIT301         495000 non-null  float64
#  19  LIT301         495000 non-null  float64
#  20  MV301          495000 non-null  int64
#  21  MV302          495000 non-null  int64
#  22  MV303          495000 non-null  int64
#  23  MV304          495000 non-null  int64
#  24  P301           495000 non-null  int64
#  25  P302           495000 non-null  int64
#  26  AIT401         495000 non-null  float64
#  27  AIT402         495000 non-null  float64
#  28  FIT401         495000 non-null  float64
#  29  LIT401         495000 non-null  float64
#  30  P401           495000 non-null  int64
#  31  P402           495000 non-null  int64
#  32  P403           495000 non-null  int64
#  33  P404           495000 non-null  int64
#  34  UV401          495000 non-null  int64
#  35  AIT501         495000 non-null  float64
#  36  AIT502         495000 non-null  float64
#  37  AIT503         495000 non-null  float64
#  38  AIT504         495000 non-null  float64
#  39  FIT501         495000 non-null  float64
#  40  FIT502         495000 non-null  float64
#  41  FIT503         495000 non-null  float64
#  42  FIT504         495000 non-null  float64
#  43  P501           495000 non-null  int64
#  44  P502           495000 non-null  int64
#  45  PIT501         495000 non-null  float64
#  46  PIT502         495000 non-null  float64
#  47  PIT503         495000 non-null  float64
#  48  FIT601         495000 non-null  float64
#  49  P601           495000 non-null  int64
#  50  P602           495000 non-null  int64
#  51  P603           495000 non-null  int64
#  52  Normal/Attack  495000 non-null  object
# dtypes: float64(25), int64(26), object(2)
# memory usage: 200.2+ MB

# %%
df.columns
# Out:
# Index([' Timestamp', 'FIT101', 'LIT101', 'MV101', 'P101', 'P102', 'AIT201',
#        'AIT202', 'AIT203', 'FIT201', 'MV201', 'P201', 'P202', 'P203', 'P204',
#        'P205', 'P206', 'DPIT301', 'FIT301', 'LIT301', 'MV301', 'MV302',
#        'MV303', 'MV304', 'P301', 'P302', 'AIT401', 'AIT402', 'FIT401',
#        'LIT401', 'P401', 'P402', 'P403', 'P404', 'UV401', 'AIT501', 'AIT502',
#        'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501',
#        'P502', 'PIT501', 'PIT502', 'PIT503', 'FIT601', 'P601', 'P602', 'P603',
#        'Normal/Attack'],
#       dtype='object')

# %%
filename = filename[:-5] + '_corr.csv'
filename
# Out:
# 'SWaT_Dataset_Normal_v1_corr.csv'

# %%
df.to_csv(filename, index=False)

# %% [markdown]
# # 2. Анализ данных

# %% [markdown]
# ## 2.1. Загрузка обработанных данных

# %%
# %%time
df = pd.read_csv(filename)
df.head(5)
# Out:
# CPU times: total: 2.2 s
# Wall time: 2.21 s
#                 Timestamp  FIT101    LIT101  MV101  P101  P102    AIT201  \
# 0   22/12/2015 4:30:00 PM     0.0  124.3135      1     1     1  251.9226
# 1   22/12/2015 4:30:01 PM     0.0  124.3920      1     1     1  251.9226
# 2   22/12/2015 4:30:02 PM     0.0  124.4705      1     1     1  251.9226
# 3   22/12/2015 4:30:03 PM     0.0  124.6668      1     1     1  251.9226
# 4   22/12/2015 4:30:04 PM     0.0  124.5098      1     1     1  251.9226
#
#      AIT202    AIT203  FIT201  ...  P501  P502    PIT501  PIT502  PIT503  \
# 0  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 1  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 2  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 3  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
# 4  8.313446  312.7916     0.0  ...     1     1  9.100231     0.0  3.3485
#
#      FIT601  P601  P602  P603  Normal/Attack
# 0  0.000256     1     1     1         Normal
# 1  0.000256     1     1     1         Normal
# 2  0.000256     1     1     1         Normal
# 3  0.000256     1     1     1         Normal
# 4  0.000256     1     1     1         Normal
#
# [5 rows x 53 columns]

# %% [markdown]
# ## 2.2. Статистики по данным

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495000 entries, 0 to 494999
# Columns: 53 entries,  Timestamp to Normal/Attack
# dtypes: float64(25), int64(26), object(2)
# memory usage: 200.2+ MB

# %%
df.describe().T
# Out:
#             count        mean         std         min         25%         50%  \
# FIT101   495000.0    1.850517    1.132519    0.000000    0.000000    2.491432
# LIT101   495000.0  587.532773  121.666482  120.623700  508.441000  525.633700
# MV101    495000.0    1.720564    0.457612    0.000000    1.000000    2.000000
# P101     495000.0    1.749149    0.433503    1.000000    1.000000    2.000000
# P102     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# AIT201   495000.0  263.783544    4.787117  251.666200  260.734400  265.284500
# AIT202   495000.0    8.388162    0.090233    8.258652    8.349654    8.366636
# AIT203   495000.0  348.379334   49.450010  312.278900  327.352000  330.966400
# FIT201   495000.0    1.834095    1.059288    0.000000    0.622016    2.443085
# MV201    495000.0    1.746497    0.443279    0.000000    2.000000    2.000000
# P201     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P202     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P203     495000.0    1.747244    0.434592    1.000000    1.000000    2.000000
# P204     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P205     495000.0    1.661558    0.473180    1.000000    1.000000    2.000000
# P206     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# DPIT301  495000.0   16.604740    6.730044    0.000000   19.604330   19.834820
# FIT301   495000.0    1.837282    0.820861    0.000000    2.208372    2.213624
# LIT301   495000.0  899.892946   93.912818  132.818500  834.241200  918.875000
# MV301    495000.0    1.005519    0.110745    0.000000    1.000000    1.000000
# MV302    495000.0    1.801925    0.414910    0.000000    2.000000    2.000000
# MV303    495000.0    1.020212    0.169591    0.000000    1.000000    1.000000
# MV304    495000.0    1.024758    0.195937    0.000000    1.000000    1.000000
# P301     495000.0    1.003594    0.059842    1.000000    1.000000    1.000000
# P302     495000.0    1.823253    0.381455    1.000000    2.000000    2.000000
# AIT401   495000.0  124.717129   54.808264    0.000000  148.803200  148.803200
# AIT402   495000.0  171.287752   12.916126  153.781100  161.958500  165.726700
# FIT401   495000.0    1.704737    0.094163    0.000000    1.699548    1.708775
# LIT401   495000.0  882.836933   87.871676  130.389600  842.207200  892.271200
# P401     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P402     495000.0    1.997051    0.054229    1.000000    2.000000    2.000000
# P403     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P404     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# UV401    495000.0    1.997044    0.054285    1.000000    2.000000    2.000000
# AIT501   495000.0    7.872306    0.042777    7.411433    7.857793    7.878942
# AIT502   495000.0  159.282508   13.411621  142.348100  147.808300  153.960500
# AIT503   495000.0  266.890181    5.218815  252.082800  264.803900  267.848000
# AIT504   495000.0   12.083752    6.437542    7.344271   11.074080   11.766210
# FIT501   495000.0    1.714675    0.094700    0.001282    1.708664    1.717765
# FIT502   495000.0    1.272488    0.072679    0.000640    1.261432    1.273985
# FIT503   495000.0    0.736139    0.040706    0.001664    0.734757    0.739110
# FIT504   495000.0    0.307254    0.017413    0.000000    0.306633    0.308362
# P501     495000.0    1.996893    0.055654    1.000000    2.000000    2.000000
# P502     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# PIT501   495000.0  251.780601   13.600787    8.891951  250.000000  253.044100
# PIT502   495000.0    1.187011    0.204781    0.000000    1.057252    1.121328
# PIT503   495000.0  190.928428   10.614230    3.108177  189.022000  191.986000
# FIT601   495000.0    0.014427    0.148934    0.000000    0.000000    0.000064
# P601     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
# P602     495000.0    1.007943    0.088771    1.000000    1.000000    1.000000
# P603     495000.0    1.000000    0.000000    1.000000    1.000000    1.000000
#
#                 75%          max
# FIT101     2.592000     2.745092
# LIT101   676.717500   817.556500
# MV101      2.000000     2.000000
# P101       2.000000     2.000000
# P102       1.000000     1.000000
# AIT201   266.982800   272.526300
# AIT202     8.407652     8.988273
# AIT203   335.349900   567.469900
# FIT201     2.451799     2.487938
# MV201      2.000000     2.000000
# P201       1.000000     1.000000
# P202       1.000000     1.000000
# P203       2.000000     2.000000
# P204       1.000000     1.000000
# P205       2.000000     2.000000
# P206       1.000000     1.000000
# DPIT301   19.978870    21.099300
# FIT301     2.217340     2.358774
# LIT301   964.376200  1014.724000
# MV301      1.000000     2.000000
# MV302      2.000000     2.000000
# MV303      1.000000     2.000000
# MV304      1.000000     2.000000
# P301       1.000000     2.000000
# P302       2.000000     2.000000
# AIT401   148.808000   148.856100
# AIT402   181.748300   235.708800
# FIT401     1.719668     1.747862
# LIT401   933.952800  1003.935000
# P401       1.000000     1.000000
# P402       2.000000     2.000000
# P403       1.000000     1.000000
# P404       1.000000     1.000000
# UV401      2.000000     2.000000
# AIT501     7.895604     7.925084
# AIT502   171.468900   218.328600
# AIT503   270.347400   283.356800
# AIT504    12.266090   227.172500
# FIT501     1.730582     1.757754
# FIT502     1.291789     1.361983
# FIT503     0.742182     0.763691
# FIT504     0.310284     0.317010
# P501       2.000000     2.000000
# P502       1.000000     1.000000
# PIT501   255.046800   264.643700
# PIT502     1.217441     3.668343
# PIT503   193.860500   200.637600
# FIT601     0.000064     1.746131
# P601       1.000000     1.000000
# P602       1.000000     2.000000
# P603       1.000000     1.000000

# %% [markdown]
# ### 2.2.1. Определение типа признаков (непрерывные, булевые, категориальные)

# %%
const_columns = []
bool_columns = []
cat_columns = []

for column in df.columns:
    nunique = df[column].nunique()
    match nunique:
        case 1:    
            print(f"column {column} has only one value: {df[column].unique()[0]}")
            const_columns.append(column)
        case 2:    
            print(f"column {column} has only two values: {df[column].unique()}")
            bool_columns.append(column)
        case _ if nunique < 5: 
            print(f"column {column} has only {nunique} values: {df[column].unique()}")
            cat_columns.append(column)
# Out:
# column MV101 has only 3 values: [1 0 2]
# column P101 has only two values: [1 2]
# column P102 has only one value: 1
# column MV201 has only 3 values: [1 0 2]
# column P201 has only one value: 1
# column P202 has only one value: 1
# column P203 has only two values: [1 2]
# column P204 has only one value: 1
# column P205 has only two values: [1 2]
# column P206 has only one value: 1
# column MV301 has only 3 values: [1 0 2]
# column MV302 has only 3 values: [1 0 2]
# column MV303 has only 3 values: [1 0 2]
# column MV304 has only 3 values: [1 0 2]
# column P301 has only two values: [1 2]
# column P302 has only two values: [1 2]
# column P401 has only one value: 1
# column P402 has only two values: [1 2]
# column P403 has only one value: 1
# column P404 has only one value: 1
# column UV401 has only two values: [1 2]
# column P501 has only two values: [1 2]
# column P502 has only one value: 1
# column P601 has only one value: 1
# column P602 has only two values: [1 2]
# column P603 has only one value: 1
# column Normal/Attack has only one value: Normal

# %% [markdown]
# ### 2.2.2. Удаление признаков-констант

# %%
df = df.drop(const_columns, axis = 1)
df[bool_columns+cat_columns] = df[bool_columns+cat_columns].astype("category")
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495000 entries, 0 to 494999
# Columns: 41 entries,  Timestamp to P602
# dtypes: category(15), float64(25), object(1)
# memory usage: 105.3+ MB

# %%
df
# Out:
#                      Timestamp    FIT101    LIT101 MV101 P101    AIT201  \
# 0        22/12/2015 4:30:00 PM  0.000000  124.3135     1    1  251.9226
# 1        22/12/2015 4:30:01 PM  0.000000  124.3920     1    1  251.9226
# 2        22/12/2015 4:30:02 PM  0.000000  124.4705     1    1  251.9226
# 3        22/12/2015 4:30:03 PM  0.000000  124.6668     1    1  251.9226
# 4        22/12/2015 4:30:04 PM  0.000000  124.5098     1    1  251.9226
# ...                        ...       ...       ...   ...  ...       ...
# 494995   28/12/2015 9:59:55 AM  2.460366  523.0430     2    2  262.0161
# 494996   28/12/2015 9:59:56 AM  2.448836  522.9645     2    2  262.0161
# 494997   28/12/2015 9:59:57 AM  2.434744  522.8860     2    2  262.0161
# 494998   28/12/2015 9:59:58 AM  2.428338  522.9252     2    2  262.0161
# 494999   28/12/2015 9:59:59 AM  2.427057  522.8467     2    2  262.0161
#
#           AIT202    AIT203    FIT201 MV201  ...    FIT501    FIT502    FIT503  \
# 0       8.313446  312.7916  0.000000     1  ...  0.001538  0.001409  0.001664
# 1       8.313446  312.7916  0.000000     1  ...  0.001538  0.001409  0.001664
# 2       8.313446  312.7916  0.000000     1  ...  0.001538  0.001409  0.001664
# 3       8.313446  312.7916  0.000000     1  ...  0.001538  0.001409  0.001664
# 4       8.313446  312.7916  0.000000     1  ...  0.001538  0.001409  0.001664
# ...          ...       ...       ...   ...  ...       ...       ...       ...
# 494995  8.396437  328.5055  2.442316     2  ...  1.726352  1.292430  0.735269
# 494996  8.396437  328.5055  2.442316     2  ...  1.724942  1.281158  0.735269
# 494997  8.396437  328.6337  2.444879     2  ...  1.723789  1.272576  0.735269
# 494998  8.396437  328.6337  2.445391     2  ...  1.723789  1.272576  0.735269
# 494999  8.396437  328.6337  2.445391     2  ...  1.723789  1.279621  0.735269
#
#           FIT504  P501      PIT501    PIT502    PIT503    FIT601 P602
# 0       0.000000     1    9.100231  0.000000    3.3485  0.000256    1
# 1       0.000000     1    9.100231  0.000000    3.3485  0.000256    1
# 2       0.000000     1    9.100231  0.000000    3.3485  0.000256    1
# 3       0.000000     1    9.100231  0.000000    3.3485  0.000256    1
# 4       0.000000     1    9.100231  0.000000    3.3485  0.000256    1
# ...          ...   ...         ...       ...       ...       ...  ...
# 494995  0.308619     2  250.817100  1.778105  189.8552  0.000128    1
# 494996  0.308619     2  250.817100  1.778105  189.5027  0.000128    1
# 494997  0.308619     2  250.817100  1.778105  189.5027  0.000128    1
# 494998  0.308619     2  250.817100  1.649953  189.5027  0.000128    1
# 494999  0.307786     2  250.865200  1.649953  189.5988  0.000128    1
#
# [495000 rows x 41 columns]

# %%
df.columns
# Out:
# Index([' Timestamp', 'FIT101', 'LIT101', 'MV101', 'P101', 'AIT201', 'AIT202',
#        'AIT203', 'FIT201', 'MV201', 'P203', 'P205', 'DPIT301', 'FIT301',
#        'LIT301', 'MV301', 'MV302', 'MV303', 'MV304', 'P301', 'P302', 'AIT401',
#        'AIT402', 'FIT401', 'LIT401', 'P402', 'UV401', 'AIT501', 'AIT502',
#        'AIT503', 'AIT504', 'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501',
#        'PIT501', 'PIT502', 'PIT503', 'FIT601', 'P602'],
#       dtype='object')

# %% [markdown]
# ## 2.3. Преобразование времени

# %% [markdown]
# Пробуем преобразовать timestamp стандартным методом pd.to_datetime

# %%
try:
    pd.to_datetime(df[' Timestamp'], format = "%d/%m/%Y %H:%M:%S %p")
except Exception as exc:
    print(exc)
# Out:
# time data " 22/12/2015 4:30:00 PM" doesn't match format "%d/%m/%Y %H:%M:%S %p", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# Преобразование прошло, но есть предупреждения - могут быть некорректные преобразования. По хорошему нужно будет проверять

# %% [markdown]
# Сравним время работы различных способов преобразования времени

# %%
# %%time
# прямое использование to_datetime
pd.to_datetime(df[' Timestamp'].str.strip(), format = "%d/%m/%Y %H:%M:%S %p")
# Out:
# CPU times: total: 1.56 s
# Wall time: 1.59 s
# 0        2015-12-22 04:30:00
# 1        2015-12-22 04:30:01
# 2        2015-12-22 04:30:02
# 3        2015-12-22 04:30:03
# 4        2015-12-22 04:30:04
#                  ...
# 494995   2015-12-28 09:59:55
# 494996   2015-12-28 09:59:56
# 494997   2015-12-28 09:59:57
# 494998   2015-12-28 09:59:58
# 494999   2015-12-28 09:59:59
# Name:  Timestamp, Length: 495000, dtype: datetime64[ns]

# %%
# %%time
# использование to_datetime + apply
df[' Timestamp'].str.strip().apply(pd.to_datetime, format = "%d/%m/%Y %H:%M:%S %p")
# Out:
# CPU times: total: 36.2 s
# Wall time: 36.7 s
# 0        2015-12-22 04:30:00
# 1        2015-12-22 04:30:01
# 2        2015-12-22 04:30:02
# 3        2015-12-22 04:30:03
# 4        2015-12-22 04:30:04
#                  ...
# 494995   2015-12-28 09:59:55
# 494996   2015-12-28 09:59:56
# 494997   2015-12-28 09:59:57
# 494998   2015-12-28 09:59:58
# 494999   2015-12-28 09:59:59
# Name:  Timestamp, Length: 495000, dtype: datetime64[ns]

# %%
# %%time
# использование to_datetime + FOR
for s in df[' Timestamp']:
    pd.to_datetime(s.strip(), format = "%d/%m/%Y %H:%M:%S %p")
# Out:
# CPU times: total: 34 s
# Wall time: 34.3 s

# %% [markdown]
# Самый быстрый способ - прямое использование to_datetime.
#
# Преобразуем время и отсортируем по нему данные

# %%
df.index = pd.to_datetime(df[' Timestamp'].str.strip(), format = "%d/%m/%Y %H:%M:%S %p")
df = df.drop(' Timestamp', axis=1).sort_index()
df.index
# Out:
# DatetimeIndex(['2015-12-22 04:30:00', '2015-12-22 04:30:01',
#                '2015-12-22 04:30:02', '2015-12-22 04:30:03',
#                '2015-12-22 04:30:04', '2015-12-22 04:30:05',
#                '2015-12-22 04:30:06', '2015-12-22 04:30:07',
#                '2015-12-22 04:30:08', '2015-12-22 04:30:09',
#                ...
#                '2015-12-28 12:59:50', '2015-12-28 12:59:51',
#                '2015-12-28 12:59:52', '2015-12-28 12:59:53',
#                '2015-12-28 12:59:54', '2015-12-28 12:59:55',
#                '2015-12-28 12:59:56', '2015-12-28 12:59:57',
#                '2015-12-28 12:59:58', '2015-12-28 12:59:59'],
#               dtype='datetime64[ns]', name=' Timestamp', length=495000, freq=None)

# %% [markdown]
# ## 2.4. Анализ непрерывных и категориальных признаков

# %%
df.describe().T
# Out:
#             count        mean         std         min         25%         50%  \
# FIT101   495000.0    1.850517    1.132519    0.000000    0.000000    2.491432
# LIT101   495000.0  587.532773  121.666482  120.623700  508.441000  525.633700
# AIT201   495000.0  263.783544    4.787117  251.666200  260.734400  265.284500
# AIT202   495000.0    8.388162    0.090233    8.258652    8.349654    8.366636
# AIT203   495000.0  348.379334   49.450010  312.278900  327.352000  330.966400
# FIT201   495000.0    1.834095    1.059288    0.000000    0.622016    2.443085
# DPIT301  495000.0   16.604740    6.730044    0.000000   19.604330   19.834820
# FIT301   495000.0    1.837282    0.820861    0.000000    2.208372    2.213624
# LIT301   495000.0  899.892946   93.912818  132.818500  834.241200  918.875000
# AIT401   495000.0  124.717129   54.808264    0.000000  148.803200  148.803200
# AIT402   495000.0  171.287752   12.916126  153.781100  161.958500  165.726700
# FIT401   495000.0    1.704737    0.094163    0.000000    1.699548    1.708775
# LIT401   495000.0  882.836933   87.871676  130.389600  842.207200  892.271200
# AIT501   495000.0    7.872306    0.042777    7.411433    7.857793    7.878942
# AIT502   495000.0  159.282508   13.411621  142.348100  147.808300  153.960500
# AIT503   495000.0  266.890181    5.218815  252.082800  264.803900  267.848000
# AIT504   495000.0   12.083752    6.437542    7.344271   11.074080   11.766210
# FIT501   495000.0    1.714675    0.094700    0.001282    1.708664    1.717765
# FIT502   495000.0    1.272488    0.072679    0.000640    1.261432    1.273985
# FIT503   495000.0    0.736139    0.040706    0.001664    0.734757    0.739110
# FIT504   495000.0    0.307254    0.017413    0.000000    0.306633    0.308362
# PIT501   495000.0  251.780601   13.600787    8.891951  250.000000  253.044100
# PIT502   495000.0    1.187011    0.204781    0.000000    1.057252    1.121328
# PIT503   495000.0  190.928428   10.614230    3.108177  189.022000  191.986000
# FIT601   495000.0    0.014427    0.148934    0.000000    0.000000    0.000064
#
#                 75%          max
# FIT101     2.592000     2.745092
# LIT101   676.717500   817.556500
# AIT201   266.982800   272.526300
# AIT202     8.407652     8.988273
# AIT203   335.349900   567.469900
# FIT201     2.451799     2.487938
# DPIT301   19.978870    21.099300
# FIT301     2.217340     2.358774
# LIT301   964.376200  1014.724000
# AIT401   148.808000   148.856100
# AIT402   181.748300   235.708800
# FIT401     1.719668     1.747862
# LIT401   933.952800  1003.935000
# AIT501     7.895604     7.925084
# AIT502   171.468900   218.328600
# AIT503   270.347400   283.356800
# AIT504    12.266090   227.172500
# FIT501     1.730582     1.757754
# FIT502     1.291789     1.361983
# FIT503     0.742182     0.763691
# FIT504     0.310284     0.317010
# PIT501   255.046800   264.643700
# PIT502     1.217441     3.668343
# PIT503   193.860500   200.637600
# FIT601     0.000064     1.746131

# %% [markdown]
# В категориальные запишем в т.ч. булевые, для упрощения. Остальные - в непрерывные

# %%
cat_columns = bool_columns+cat_columns
cont_columns = list(set(df.columns) - set(cat_columns))
cont_columns
# Out:
# ['AIT201',
#  'AIT502',
#  'FIT301',
#  'AIT501',
#  'LIT401',
#  'AIT202',
#  'AIT503',
#  'PIT503',
#  'PIT502',
#  'FIT501',
#  'LIT301',
#  'FIT503',
#  'AIT504',
#  'FIT502',
#  'DPIT301',
#  'FIT401',
#  'AIT401',
#  'AIT402',
#  'FIT101',
#  'FIT504',
#  'FIT601',
#  'AIT203',
#  'LIT101',
#  'FIT201',
#  'PIT501']

# %% [markdown]
# ### 2.4.1. Непрерывные признаки

# %%
df[cont_columns].plot(
    kind='kde', 
    figsize=(10,50),
    subplots=True,
    sharex=False, 
    title='Kernel Density Estimation'
)

plt.show()

# %%
df[cont_columns].boxplot(figsize=(20,10))
plt.title("Диаграмма размаха")
plt.show()

# %% [markdown]
# ### 2.4.2. Категориальные/булевые признаки

# %%
ncols = 8
nrows = len(cat_columns) // ncols
if len(cat_columns) % ncols != 0: nrows += 1

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(20,10))


for row, ax_row in enumerate(axes):
    for ax, col in zip(ax_row, cat_columns[row*ncols:(row+1)*ncols]):
        df[col].value_counts(normalize=True).plot.bar(ax=ax, title=col)

# %% [markdown]
# ### 2.4.2. Анализ корреляции

# %%
#plt.figure(figsize=(10,10))
sns.heatmap(df[sorted(cont_columns, key=lambda x: x[3])].corr(), cmap="YlGnBu")
# Out:
# <Axes: >

# %%
df_corr = df[sorted(cont_columns, key=lambda x: x[3])].corr()

# %% [markdown]
# Найдем наиболее скоррелированные признаки

# %%
from itertools import combinations

unique_pairs = list(combinations(df_corr.columns, 2))
most_correlated = pd.DataFrame(columns=['1st', '2nd', 'value'])

for row, col in unique_pairs:
    corr_value = df_corr.loc[row, col]
    if corr_value >= 0.75:
        most_correlated.loc[most_correlated.shape[0]] = pd.Series({'1st': row, '2nd': col, 'value': corr_value})

most_correlated.sort_values('value', ascending=False)
# Out:
#        1st      2nd     value
# 2   FIT401   FIT501  0.999726
# 12  PIT503   PIT501  0.998741
# 19  FIT503   PIT501  0.991066
# 18  FIT503   FIT504  0.990804
# 9   PIT503   FIT503  0.984118
# 7   AIT402   AIT502   0.98012
# 14  FIT501   FIT502  0.978631
# 4   FIT401   FIT502  0.978103
# 0   FIT301  DPIT301  0.977377
# 22  FIT504   PIT501   0.97214
# 3   FIT401   FIT503  0.965259
# 13  FIT501   FIT503  0.964051
# 11  PIT503   FIT504  0.962378
# 5   FIT401   FIT504  0.955665
# 15  FIT501   FIT504  0.954739
# 6   FIT401   PIT501  0.933056
# 16  FIT501   PIT501  0.931214
# 17  FIT503   FIT502  0.922764
# 20  FIT502   FIT504  0.917587
# 1   FIT401   PIT503   0.91614
# 8   PIT503   FIT501  0.914053
# 21  FIT502   PIT501  0.881215
# 10  PIT503   FIT502  0.860704

# %% [markdown]
# # 3. Работа с временным рядом

# %% [markdown]
# ## 3.1. Визуализация пропущенных значений

# %% [markdown]
# Можно использовать тепловую карту из sns и метод isna для датафрейма, но мы будем использовать модуль missingno - так проще, но его надо установить
#
# pip install missingno

# %%
import missingno

missingno.matrix(df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# FIT101     0
# LIT101     0
# MV101      0
# P101       0
# AIT201     0
# AIT202     0
# AIT203     0
# FIT201     0
# MV201      0
# P203       0
# P205       0
# DPIT301    0
# FIT301     0
# LIT301     0
# MV301      0
# MV302      0
# MV303      0
# MV304      0
# P301       0
# P302       0
# AIT401     0
# AIT402     0
# FIT401     0
# LIT401     0
# P402       0
# UV401      0
# AIT501     0
# AIT502     0
# AIT503     0
# AIT504     0
# FIT501     0
# FIT502     0
# FIT503     0
# FIT504     0
# P501       0
# PIT501     0
# PIT502     0
# PIT503     0
# FIT601     0
# P602       0
# dtype: int64

# %% [markdown]
# пропущенных значений нет, можно было бы это понять из info, но если бы были - эта визуализация бы нам помогла

# %% [markdown]
# ## 3.2. Ресэмплирование и сглаживание

# %%
df.head(5)
# Out:
#                      FIT101    LIT101 MV101 P101    AIT201    AIT202  \
#  Timestamp
# 2015-12-22 04:30:00     0.0  124.3135     1    1  251.9226  8.313446
# 2015-12-22 04:30:01     0.0  124.3920     1    1  251.9226  8.313446
# 2015-12-22 04:30:02     0.0  124.4705     1    1  251.9226  8.313446
# 2015-12-22 04:30:03     0.0  124.6668     1    1  251.9226  8.313446
# 2015-12-22 04:30:04     0.0  124.5098     1    1  251.9226  8.313446
#
#                        AIT203  FIT201 MV201 P203  ...    FIT501    FIT502  \
#  Timestamp                                        ...
# 2015-12-22 04:30:00  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 04:30:01  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 04:30:02  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 04:30:03  312.7916     0.0     1    1  ...  0.001538  0.001409
# 2015-12-22 04:30:04  312.7916     0.0     1    1  ...  0.001538  0.001409
#
#                        FIT503  FIT504 P501    PIT501 PIT502  PIT503    FIT601  \
#  Timestamp
# 2015-12-22 04:30:00  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 04:30:01  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 04:30:02  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 04:30:03  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
# 2015-12-22 04:30:04  0.001664     0.0    1  9.100231    0.0  3.3485  0.000256
#
#                     P602
#  Timestamp
# 2015-12-22 04:30:00    1
# 2015-12-22 04:30:01    1
# 2015-12-22 04:30:02    1
# 2015-12-22 04:30:03    1
# 2015-12-22 04:30:04    1
#
# [5 rows x 40 columns]

# %% [markdown]
# Изначально данные в датафрейме идут каждую секунду.
#
# Предположим, что наши процессы достаточно инерционные и нам хватает периода в 1 минуту - это будет влиять на скорость обработки данных, их объем.
# При помощи функции resample мы будем аггрегировать данные по 1 минуте, считая среднее значение за минуту. Применим это преобразование только к непрерывным признакам, т.к. для категориальных нет такого понятия как "среднее"

# %%
df_1min = df[cont_columns].resample('1T').mean()
df_1min.head(5)
# Out:
#                          AIT201      AIT502    FIT301    AIT501      LIT401  \
#  Timestamp
# 2015-12-22 04:30:00  251.922600  175.408857  0.000256  7.444827  133.086390
# 2015-12-22 04:31:00  251.922600  175.632332  0.000256  7.444641  132.646765
# 2015-12-22 04:32:00  251.916190  175.797222  0.000256  7.442937  132.498727
# 2015-12-22 04:33:00  251.841938  175.976200  0.000256  7.440187  132.446173
# 2015-12-22 04:34:00  251.841435  176.083923  0.000256  7.439844  132.327617
#
#                        AIT202      AIT503    PIT503  PIT502    FIT501  ...  \
#  Timestamp                                                             ...
# 2015-12-22 04:30:00  8.310001  260.702400  3.348500     0.0  0.001538  ...
# 2015-12-22 04:31:00  8.309750  260.702400  3.348500     0.0  0.001538  ...
# 2015-12-22 04:32:00  8.311182  260.756885  3.291090     0.0  0.001538  ...
# 2015-12-22 04:33:00  8.310124  260.755820  3.260382     0.0  0.001538  ...
# 2015-12-22 04:34:00  8.310087  260.766500  3.255843     0.0  0.001538  ...
#
#                      FIT401  AIT401      AIT402    FIT101    FIT504    FIT601  \
#  Timestamp
# 2015-12-22 04:30:00     0.0     0.0  169.287813  0.000000  0.000000  0.000256
# 2015-12-22 04:31:00     0.0     0.0  169.565088  0.000016  0.000000  0.000256
# 2015-12-22 04:32:00     0.0     0.0  169.691108  0.000000  0.000017  0.000256
# 2015-12-22 04:33:00     0.0     0.0  169.833363  0.000000  0.000000  0.000256
# 2015-12-22 04:34:00     0.0     0.0  170.149130  0.000000  0.000000  0.000256
#
#                          AIT203      LIT101  FIT201    PIT501
#  Timestamp
# 2015-12-22 04:30:00  312.933878  124.158442     0.0  9.079136
# 2015-12-22 04:31:00  313.296585  123.908527     0.0  9.068188
# 2015-12-22 04:32:00  313.669147  123.548057     0.0  9.068188
# 2015-12-22 04:33:00  313.957082  123.040390     0.0  9.068188
# 2015-12-22 04:34:00  314.210027  123.389078     0.0  9.068188
#
# [5 rows x 25 columns]

# %% [markdown]
# Также мы можем применить к этим данным сглаживание

# %%
df_rolling = df[cont_columns].rolling(60).mean()

# %%
col = 'AIT503'

plt.figure(figsize=(20,5))

plt.plot(df[col].loc['2015-12-25 02:00:00':'2015-12-25 02:10:00'], alpha=0.5, label='original')
plt.plot(df_rolling[col].loc['2015-12-25 02:00:00':'2015-12-25 02:10:00'], label='rolling')
plt.plot(df_1min[col].loc['2015-12-25 02:00:00':'2015-12-25 02:10:00'], label='resample')

plt.title('Сглаженный, ресэмплированный и оригинальный графики')
plt.legend()
plt.show()
